# %%
# Ensure required columns exist
required = ['LIFESTAGE', 'PREMIUM_CUSTOMER']
issing = [c for c in required if c not in df.columns]
if missing:
    raise KeyError(f"Missing required columns: {missing}")

# Optional: inspect a small sample before sorting
