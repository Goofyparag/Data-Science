# %%
import  pandas as pd

# %%
s= pd.Series([10,30,50,70,90],index=['a','b','c','d','e'])
print(s)
#s.head()
#s.tail()
#s.index
#s.values
#s.dtype
#s.ndim
#s.shape
#s.size
# Out:
# a    10
# b    30
# c    50
# d    70
# e    90
# dtype: int64

# %%
s.ndim
# Out:
# 1

# %% [markdown]
# finds the diamension of the arr or vector and matrix

# %%
s.dtype
# Out:
# dtype('int64')

# %% [markdown]
# gives the data type of the arr

# %%
s.values
# Out:
# array([10, 30, 50, 70, 90], dtype=int64)

# %% [markdown]
# gives the value of arr

# %%
s.size
# Out:
# 5

# %% [markdown]
# give the size or numbers of the element in arr

# %%
s.head()
# Out:
# a    10
# b    30
# c    50
# d    70
# e    90
# dtype: int64

# %% [markdown]
# print the top 5 values

# %%
s.tail()
# Out:
# a    10
# b    30
# c    50
# d    70
# e    90
# dtype: int64

# %% [markdown]
# print the down 5 values

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# print the index of the arr

# %%
s.shape
# Out:
# (5,)

# %% [markdown]
# print the numbers of values in arr

# %%
df =pd.DataFrame({
    "name":["parag","tiwari","kumar","singh"],
    "age":[20,25,30,40],
    "city":["delhi","mumbai","bangalore","chennai"] 
},index=["a","b","c","d"])
print(df)
# Out:
#      name  age       city
# a   parag   20      delhi
# b  tiwari   25     mumbai
# c   kumar   30  bangalore
# d   singh   40    chennai

# %%
#human["LYLTY_CARD_NBR"].nunique()
human["LYLTY_CARD_NBR"].mean()
# Out:
# 136185.9317703099

# %%
human["LYLTY_CARD_NBR"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 72637 entries, 0 to 72636
# Series name: LYLTY_CARD_NBR
# Non-Null Count  Dtype
# --------------  -----
# 72637 non-null  int64
# dtypes: int64(1)
# memory usage: 567.6 KB

# %%
human.columns
# Out:
# Index(['LYLTY_CARD_NBR', 'LIFESTAGE', 'PREMIUM_CUSTOMER'], dtype='object')

# %% [markdown]
# print the columns
