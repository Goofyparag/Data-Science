# %%
import pandas as pd

# %%
df= pd.read_csv("sales_data_sample.csv", encoding="latin1")

# %%
df.sample(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2770        10106               48      52.64               15  2526.72
# 1734        10314               39      37.13               15  1448.07
# 2159        10259               45      86.68               11  3900.60
# 1843        10396               27      83.20                7  2246.40
# 2686        10375               44     100.00               11  5208.72
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2770   2/17/2003 0:00  Shipped       1         2     2003  ...
# 1734  10/22/2004 0:00  Shipped       4        10     2004  ...
# 2159   6/15/2004 0:00  Shipped       2         6     2004  ...
# 1843   3/23/2005 0:00  Shipped       1         3     2005  ...
# 2686    2/3/2005 0:00  Shipped       1         2     2005  ...
#
#                                  ADDRESSLINE1  ADDRESSLINE2        CITY STATE  \
# ...

# %%
ds=pd.read_excel("Inventory-Records-Sample-Data.xlsx")

# %%
# !pip install xlrd>=1.2.0

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
ds
# Out:
#     Unnamed: 0              Unnamed: 1                   Unnamed: 2  \
# 0          NaN       Excel Sample Data                          NaN
# 1          NaN                     NaN                          NaN
# 2          NaN  Inventory Records Data                          NaN
# 3          NaN                     NaN                          NaN
# 4          NaN              Product ID                 Product Name
# 5          NaN                    P101                       Laptop
# 6          NaN                    P102                      Monitor
# 7          NaN                    P103                     Keyboard
# 8          NaN                    P104                   Headphones
# 9          NaN                    P105                   Smartphone
# 10         NaN                    P106                       Tablet
# 11         NaN                    P107                       Router
# 12         NaN                    P108          External Hard Drive
# ...

# %%
ds.head()
# Out:
#    Unnamed: 0              Unnamed: 1    Unnamed: 2       Unnamed: 3  \
# 0         NaN       Excel Sample Data           NaN              NaN
# 1         NaN                     NaN           NaN              NaN
# 2         NaN  Inventory Records Data           NaN              NaN
# 3         NaN                     NaN           NaN              NaN
# 4         NaN              Product ID  Product Name  Opening \nStock
#
#             Unnamed: 4              Unnamed: 5       Unnamed: 6  \
# 0                  NaN                     NaN              NaN
# 1                  NaN                     NaN              NaN
# 2                  NaN                     NaN              NaN
# 3                  NaN                     NaN              NaN
# 4  Purchase/\nStock in  Number of \nUnits Sold  Hand-In-\nStock
#
#                     Unnamed: 7               Unnamed: 8
# 0                          NaN                      NaN
# ...

# %%
dj=pd.read_json("sample_Data.json")

# %%
dj
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...
